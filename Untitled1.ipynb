# %%
import pandas as pd
df = pd.read_csv("C:\stock.csv")
df
# Out:
#   new header     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
df=pd.read_csv("C:\stock.csv",skiprows=1)
df
# Out:
#   Unnamed: 0     Unnamed: 1  Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0      GOOGL          27.82          87        845     larry page
# 1        WMT           4.61         484         65           n.a.
# 2       MSFT             -1          85         64     bill gates
# 3       RIL   not available          50       1023  mukesh ambani
# 4       TATA            5.6          -1       n.a.     ratan tata

# %%
 df=pd.read_csv("C:\stock.csv",header=1)

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("C:\stock.csv", header=None,names=["ticker","eps","revenue","price","people"])
df
# Out:
#        ticker            eps  revenue price         people
# 0  new header            NaN      NaN   NaN            NaN
# 1         NaN            NaN      NaN   NaN            NaN
# 2       GOOGL          27.82     87.0   845     larry page
# 3         WMT           4.61    484.0    65           n.a.
# 4        MSFT             -1     85.0    64     bill gates
# 5        RIL   not available     50.0  1023  mukesh ambani
# 6        TATA            5.6     -1.0  n.a.     ratan tata

# %%
df=pd.read_csv("C:\stock.csv", nrows=3)
df
# Out:
#   new header Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0    tickers        eps    revenue      price      people
# 1      GOOGL      27.82         87        845  larry page
# 2        WMT       4.61        484         65        n.a.

# %%
df=pd.read_csv("C:\stock.csv",names=["ticker","eps","revenue","price","people"])
df
# Out:
#        ticker            eps  revenue price         people
# 0  new header            NaN      NaN   NaN            NaN
# 1         NaN            NaN      NaN   NaN            NaN
# 2       GOOGL          27.82     87.0   845     larry page
# 3         WMT           4.61    484.0    65           n.a.
# 4        MSFT             -1     85.0    64     bill gates
# 5        RIL   not available     50.0  1023  mukesh ambani
# 6        TATA            5.6     -1.0  n.a.     ratan tata

# %%
df.head(3)
# Out:
#        ticker    eps  revenue  price      people
# 0  new header    NaN      NaN    NaN         NaN
# 1     tickers    eps  revenue  price      people
# 2       GOOGL  27.82       87    845  larry page

# %%
df=pd.read_csv("C:\stock.csv",nrows=3)
df
# Out:
#   new header Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0    tickers        eps    revenue      price      people
# 1      GOOGL      27.82         87        845  larry page
# 2        WMT       4.61        484         65        n.a.

# %%
df=pd.read_csv("C:\stock.csv", na_values={'eps': ["not available","n.a.",-1],
                                          'people':["not available","n.a."]})
df
# Out:
#   new header     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
df.columns
# Out:
# Index(['new header', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df.cloumns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cloumns'
