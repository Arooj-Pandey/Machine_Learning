# %%
import pandas as pd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Microsoft_Excel')
df
# Out:
# [                                                   0  \
#  0                                                NaN
#  1  A simple bar graph being created in Excel, run...
#  2                                       Developer(s)
#  3                                    Initial release
#  4                                     Stable release
#  5                                         Written in
#  6                                   Operating system
#  7                                               Type
#  8                                            License
#  9                                            Website
#
#                                                     1
#  0                                                NaN
#  1  A simple bar graph being created in Excel, run...
#  2                                          Microsoft
#  3                    November 19, 1987; 35 years ago
#  4  2103 (16.0.13901.20400)  / April 13, 2021; 2 y...
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
"https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"
# ----> 2 pd.read_html(url)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
import pandas as pd
df=pd.read_html('https://erp.aktu.ac.in/webpages/oneview/OVEngine.aspx?enc=yUxzGv3uUAGQ7wqlvkd1Gd/yEQttL8peolGN64da5BmCfWOoNuUlrRR/cP+e4eu8')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_html('https://erp.aktu.ac.in/webpages/oneview/OVEngine.aspx?enc=yUxzGv3uUAGQ7wqlvkd1Gd/yEQttL8peolGN64da5BmCfWOoNuUlrRR/cP+e4eu8')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35          7  sunny
# 2  01-03-2017           28          2   snow
# 3  01-04-2017           24          7   snow
# 4  01-05-2017           32          4   rain
# 5  01-06-2017           32          2  sunny

# %%
df=pd.read_excel('C:\\Employee Sample Data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_excel('C:\\Employee Sample Data.csv')
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.DataFrame()
#
# NameError: name 'pd' is not defined

# %%
url='https://erp.aktu.ac.in/webpages/oneview/OVEngine.aspx?enc=yUxzGv3uUAGQ7wqlvkd1Gd/yEQttL8peolGN64da5BlRxg2u6iiibk31lXQt2qC8'
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 url='https://erp.aktu.ac.in/webpages/oneview/OVEngine.aspx?enc=yUxzGv3uUAGQ7wqlvkd1Gd/yEQttL8peolGN64da5BlRxg2u6iiibk31lXQt2qC8'
# ----> 2 pd.read_html(url)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
