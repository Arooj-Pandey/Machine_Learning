# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('C:\\Users\\arooj\\Downloads\\Exercise1_gradient.csv')
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = b_curr = 0
    rate = 0.0002
    n = len(x)
    previous_cost = 0
    plt.scatter(x,y, color = 'red', marker = '+')
    for i in range(100):
        y_predicted = m_curr * x + b_curr
        plt.plot(x,y_predicted,color = 'blue')
        cost = (1/n) * sum([val**2 for val in (y - y_predicted)])
        md = -(2/n) * sum(x * (y - y_predicted))
        yd = -(2/n) * sum(y - y_predicted)
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd
        if math.isclose(cost, previous_cost, rel_tol=1e-20):
            break
        previous_cost = cost
        print("m{}, b{}, cost{}, iteration{}". format(m_curr, b_curr, cost, i))    
    return m_curr, b_curr

# %%
gradient_descent(x,y)
# Out:
# m1.9783600000000003, b0.027960000000000002, cost5199.1, iteration0
# m0.20975041279999962, b0.0030470367999999894, cost4161.482445460163, iteration1
# m1.7908456142986242, b0.025401286955264, cost3332.2237319269248, iteration2
# m0.37738163667530467, b0.005499731626422651, cost2669.4843523161976, iteration3
# m1.6409848166378898, b0.023373894401807944, cost2139.826383775145, iteration4
# m0.5113514173939655, b0.0074774305434828076, cost1716.5264071567592, iteration5
# m1.5212165764726306, b0.021771129698498662, cost1378.2272007804495, iteration6
# m0.6184191426785134, b0.009075514323270572, cost1107.8601808918404, iteration7
# m1.4254981563597626, b0.020507724625171385, cost891.7842215178443, iteration8
# m0.7039868810749315, b0.010370210797388455, cost719.0974036421305, iteration9
# m1.3490002310389348, b0.01951553325074733, cost581.0869686205, iteration10
# m0.7723719384951477, b0.01142244086408669, cost470.7897237271261, iteration11
# ...

# %%
def prediction():
    reg = LinearRegression()
    reg.fit(df[['math']],df.cs)
    return reg.intercept_, reg.coef_

# %%
if __name__ == "__main__":
    df = pd.read_csv('C:\\Users\\arooj\\Downloads\\Exercise1_gradient.csv')
    x = np.array(df.math)
    y = np.array(df.cs)
    m, b = gradient_descent(x,y)
    print(" slope{}, intercept {}".format(m, b))
    m_curr, b_curr = prediction()
    print("Using Sklearn we got slope {}, intercept {}".format(m_curr, b_curr))
# Out:
# m1.9783600000000003, b0.027960000000000002, cost5199.1, iteration0
# m0.20975041279999962, b0.0030470367999999894, cost4161.482445460163, iteration1
# m1.7908456142986242, b0.025401286955264, cost3332.2237319269248, iteration2
# m0.37738163667530467, b0.005499731626422651, cost2669.4843523161976, iteration3
# m1.6409848166378898, b0.023373894401807944, cost2139.826383775145, iteration4
# m0.5113514173939655, b0.0074774305434828076, cost1716.5264071567592, iteration5
# m1.5212165764726306, b0.021771129698498662, cost1378.2272007804495, iteration6
# m0.6184191426785134, b0.009075514323270572, cost1107.8601808918404, iteration7
# m1.4254981563597626, b0.020507724625171385, cost891.7842215178443, iteration8
# m0.7039868810749315, b0.010370210797388455, cost719.0974036421305, iteration9
# m1.3490002310389348, b0.01951553325074733, cost581.0869686205, iteration10
# m0.7723719384951477, b0.01142244086408669, cost470.7897237271261, iteration11
# ...
